# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import numpy as np
import warnings
import importlib
import sys
plt.rcParams["patch.force_edgecolor"] = True
plt.style.use('fivethirtyeight')
mpl.rc('patch', edgecolor = 'dimgray', linewidth=1)
# %matplotlib inline

# %%
warnings.filterwarnings('ignore')

# %%
sys.path.append("..")

# %%
from myscripts import logger_comb

# %%
from myscripts import preprocess_data

# %%
train=pd.read_csv("../data/train.csv",low_memory=False,parse_dates=[3],index_col=[0])
print(train.shape)
train.head()
# Out:
# (1017209, 18)
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                       11.0                    2007.0       1
# 2                       12.0                    2006.0       1
# 3                        9.0                    2009.0       0
# 4                        4.0                    2015.0       0
#
#    Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0              NaN              NaN              NaN
# 1             13.0           2010.0  Jan,Apr,Jul,Oct
# 2             14.0           2011.0  Jan,Apr,Jul,Oct
# 3              NaN              NaN              NaN
# 4              NaN              NaN              NaN

# %%
test=pd.read_csv("../data/test.csv",low_memory=False,parse_dates=[4],index_col=0)
print(test.shape)
test.head()
# Out:
# (41088, 17)
#    Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  SchoolHoliday  \
# 0   1      1          4 2015-09-17   1.0      1            0              0
# 1   2      3          4 2015-09-17   1.0      1            0              0
# 2   3      7          4 2015-09-17   1.0      1            0              0
# 3   4      8          4 2015-09-17   1.0      1            0              0
# 4   5      9          4 2015-09-17   1.0      1            0              0
#
#   StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0         c          a               1270.0                        9.0
# 1         a          a              14130.0                       12.0
# 2         a          c              24000.0                        4.0
# 3         a          a               7520.0                       10.0
# 4         a          c               2030.0                        8.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2006.0       1             14.0           2011.0
# 2                    2013.0       0              NaN              NaN
# 3                    2014.0       0              NaN              NaN
# 4                    2000.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2              NaN
# 3              NaN
# 4              NaN

# %%
store=pd.read_csv("../data/store.csv",low_memory=False)
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
# sample=pd.read_csv("../data/sample_submission.csv",low_memory=False)
# print(sample.shape)
# sample.head()

# %%
cat_cols=['PromoInterval','StoreType','StateHoliday','Assortment','Date']

# %%
importlib.reload(preprocess_data)
# Out:
# <module 'myscripts.preprocess_data' from '..\\myscripts\\preprocess_data.py'>

# %%
cleaner_train=preprocess_data.clean_data(train)
cleaner_test=preprocess_data.clean_data(test)

# %%
test.isna().sum()
# Out:
# Id                               0
# Store                            0
# DayOfWeek                        0
# Date                             0
# Open                            11
# Promo                            0
# StateHoliday                     0
# SchoolHoliday                    0
# StoreType                        0
# Assortment                       0
# CompetitionDistance             96
# CompetitionOpenSinceMonth    15216
# CompetitionOpenSinceYear     15216
# Promo2                           0
# Promo2SinceWeek              17232
# Promo2SinceYear              17232
# PromoInterval                17232
# dtype: int64

# %%
#fix outlier

# %%
train=cleaner_train.fix_outliers(train,['Sales','Customers','CompetitionDistance'])
test=cleaner_test.fix_outliers(test,['CompetitionDistance'])

# %%
# Impute Missing Values

# %%
train.isna().sum()
# Out:
# Store                             0
# DayOfWeek                         0
# Date                              0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# StoreType                         0
# Assortment                        0
# CompetitionDistance            2642
# CompetitionOpenSinceMonth    323348
# CompetitionOpenSinceYear     323348
# Promo2                            0
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# PromoInterval                508031
# dtype: int64

# %%
test.isna().sum()
# Out:
# Id                               0
# Store                            0
# DayOfWeek                        0
# Date                             0
# Open                            11
# Promo                            0
# StateHoliday                     0
# SchoolHoliday                    0
# StoreType                        0
# Assortment                       0
# CompetitionDistance             96
# CompetitionOpenSinceMonth    15216
# CompetitionOpenSinceYear     15216
# Promo2                           0
# Promo2SinceWeek              17232
# Promo2SinceYear              17232
# PromoInterval                17232
# dtype: int64

# %%
train[train['Promo2']==0]

# based on the table above where we have promo2 is equal to 0 means that store is not participating,
# the last three columns should be null. we can replace by them by 0 to mean that they are not available
#We shall do the same to test data
# Out:
#          Store  DayOfWeek       Date        Sales   Customers  Open  Promo  \
# 0            1          5 2015-07-31  5263.000000  555.000000     1      1
# 3            4          5 2015-07-31  5770.401742  627.693439     1      1
# 4            5          5 2015-07-31  4822.000000  559.000000     1      1
# 5            6          5 2015-07-31  5651.000000  589.000000     1      1
# 6            7          5 2015-07-31  5770.401742  627.693439     1      1
# ...        ...        ...        ...          ...         ...   ...    ...
# 1017201   1108          2 2013-01-01     0.000000    0.000000     0      0
# 1017203   1110          2 2013-01-01     0.000000    0.000000     0      0
# 1017205   1112          2 2013-01-01     0.000000    0.000000     0      0
# 1017206   1113          2 2013-01-01     0.000000    0.000000     0      0
# 1017207   1114          2 2013-01-01     0.000000    0.000000     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a          1270.000000
# 3                  0              1         c          c           620.000000
# 4                  0              1         a          a          5430.085652
# 5                  0              1         a          a           310.000000
# 6                  0              1         a          c          5430.085652
# ...              ...            ...       ...        ...                  ...
# 1017201            a              1         a          a           540.000000
# 1017203            a              1         c          c           900.000000
# 1017205            a              1         c          c          1880.000000
# 1017206            a              1         a          c          9260.000000
# 1017207            a              1         a          c           870.000000
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 3                              9.0                    2009.0       0
# 4                              4.0                    2015.0       0
# 5                             12.0                    2013.0       0
# 6                              4.0                    2013.0       0
# ...                            ...                       ...     ...
# 1017201                        4.0                    2004.0       0
# 1017203                        9.0                    2010.0       0
# 1017205                        4.0                    2006.0       0
# 1017206                        NaN                       NaN       0
# 1017207                        NaN                       NaN       0
#
#          Promo2SinceWeek  Promo2SinceYear PromoInterval
# 0                    NaN              NaN           NaN
# 3                    NaN              NaN           NaN
# 4                    NaN              NaN           NaN
# 5                    NaN              NaN           NaN
# 6                    NaN              NaN           NaN
# ...                  ...              ...           ...
# 1017201              NaN              NaN           NaN
# 1017203              NaN              NaN           NaN
# 1017205              NaN              NaN           NaN
# 1017206              NaN              NaN           NaN
# 1017207              NaN              NaN           NaN
#
# [508031 rows x 18 columns]

# %%
cleaner_train.filling_nan(train,['Promo2SinceWeek','Promo2SinceYear',],0)
cleaner_test.filling_nan(test,['Promo2SinceWeek','Promo2SinceYear',],0)

# %%
cleaner_train.filling_nan(train,['PromoInterval'],"0,0,0,0") #we have to replace with four zeros since we have four variables 
cleaner_test.filling_nan(test,['PromoInterval'],"0,0,0,0")

# %%
store[store['CompetitionOpenSinceYear'].isna()].head()
# Out:
#     Store StoreType Assortment  CompetitionDistance  \
# 11     12         a          c               1070.0
# 12     13         d          a                310.0
# 15     16         a          c               3270.0
# 18     19         a          c               3240.0
# 21     22         a          a               1040.0
#
#     CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 11                        NaN                       NaN       1
# 12                        NaN                       NaN       1
# 15                        NaN                       NaN       0
# 18                        NaN                       NaN       1
# 21                        NaN                       NaN       1
#
#     Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 11             13.0           2010.0   Jan,Apr,Jul,Oct
# 12             45.0           2009.0   Feb,May,Aug,Nov
# 15              NaN              NaN               NaN
# 18             22.0           2011.0  Mar,Jun,Sept,Dec
# 21             22.0           2012.0   Jan,Apr,Jul,Oct

# %% [markdown]
# we can see that for the first two rows, the store is starting but we have null values in CompetitionOpenSinceMonth and CompetitionOpenSinceYear. Therefore, we can impute the missing values by filling with minimun values since that nan values might be due to the fact there were already the competition since the store open

# %%
cleaner_train.filling_nan(train,['CompetitionOpenSinceMonth'],train.CompetitionOpenSinceMonth.min())
cleaner_train.filling_nan(train,['CompetitionOpenSinceYear'],train.CompetitionOpenSinceMonth.min())
cleaner_test.filling_nan(test,['CompetitionOpenSinceMonth'],test.CompetitionOpenSinceYear.min())
cleaner_test.filling_nan(test,['CompetitionOpenSinceYear'],test.CompetitionOpenSinceYear.min())

# %%
# Impute competition distance with mean

# %%
cleaner_train.filling_nan(train,['CompetitionDistance'],train.CompetitionDistance.mean())
cleaner_test.filling_nan(test,['CompetitionDistance'],test.CompetitionDistance.mean())
cleaner_test.filling_nan(test,['Open'],1)

# %%
# make Date related features

# %%
train=cleaner_train.make_datefeatures(train,'Date')
test=cleaner_test.make_datefeatures(test,'Date')

# %%
['StateHoliday','StoreType','Assortment','PromoInterval']
# Out:
# ['StateHoliday', 'StoreType', 'Assortment', 'PromoInterval']

# %%
# label encoding categorical columns

# %%
train=cleaner_train.label_encoder(train)
test=cleaner_test.label_encoder(test)

# %%
#Feature Selection

# %%
import statsmodels.api as sm
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import f1_score,confusion_matrix
# from sklearn.metrics import accuracy_score

# %%
def forward_regression(X, y,
                       threshold_in,
                       verbose=False):
    initial_list = []
    included = list(initial_list)
    while True:
        changed=False
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.idxmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))

        if not changed:
            break

    return included,model

# %%
X=train[train.columns.difference(['Sales','Date']).to_list()]
Y=train['Sales']

# %%
cols_pass,model_ols=forward_regression(X,Y,0.05,verbose=True)
# Out:
# Add  Open                           with p-value 0.0
# Add  WeekOfYear                     with p-value 0.0
# Add  dayType                        with p-value 0.0
# Add  Assortment                     with p-value 0.0
# Add  Years                          with p-value 0.0
# Add  Promo2                         with p-value 0.0
# Add  Promo2SinceWeek                with p-value 0.0
# Add  StateHoliday                   with p-value 0.0

# %%
selected_cols=[]

# %%
# MinMax Scale the Dataframe

# %%
train=cleaner_train.scale_data(train)
test=cleaner_test.scale_data(test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-ff2e699d7895> in <module>
# ----> 1 train=cleaner_train.scale_data(train)
#       2 test=cleaner_test.scale_data(test)
#
# ~\PycharmProjects\pythonProject\sales_predict\myscripts\preprocess_data.py in scale_data(self, df)
#      49     def scale_data(self, df: pd.DataFrame) -> pd.DataFrame:
#      50         scaler = MinMaxScaler()
# ---> 51         df[:] = scaler.fit_transform(df[:])
#      52         logger.info("successful scaling data")
#      53         return df
#
# c:\users\faith bagire\pycharmprojects\pythonproject\v\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# c:\users\faith bagire\pycharmprojects\pythonproject\v\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     361         # Reset internal state before fitting
#     362         self._reset()
# --> 363         return self.partial_fit(X, y)
#     364
#     365     def partial_fit(self, X, y=None):
#
# c:\users\faith bagire\pycharmprojects\pythonproject\v\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     396         X = self._validate_data(X, reset=first_pass,
#     397                                 estimator=self, dtype=FLOAT_DTYPES,
# --> 398                                 force_all_finite="allow-nan")
#     399
#     400         data_min = np.nanmin(X, axis=0)
#
# c:\users\faith bagire\pycharmprojects\pythonproject\v\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# c:\users\faith bagire\pycharmprojects\pythonproject\v\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\faith bagire\pycharmprojects\pythonproject\v\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     595
#     596         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 597             dtype_orig = np.result_type(*dtypes_orig)
#     598
#     599     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# TypeError: invalid type promotion

# %%
#Save clean and fixed train and test dataframes
test
# Out:
#           Id  Store  DayOfWeek       Date  Open  Promo  StateHoliday  \
# 0          1      1          4 2015-09-17   1.0      1             0
# 1          2      3          4 2015-09-17   1.0      1             0
# 2          3      7          4 2015-09-17   1.0      1             0
# 3          4      8          4 2015-09-17   1.0      1             0
# 4          5      9          4 2015-09-17   1.0      1             0
# ...      ...    ...        ...        ...   ...    ...           ...
# 41083  41084   1111          6 2015-08-01   1.0      0             0
# 41084  41085   1112          6 2015-08-01   1.0      0             0
# 41085  41086   1113          6 2015-08-01   1.0      0             0
# 41086  41087   1114          6 2015-08-01   1.0      0             0
# 41087  41088   1115          6 2015-08-01   1.0      0             0
#
#        SchoolHoliday  StoreType  Assortment  ...  CompetitionOpenSinceYear  \
# 0                  0          0           0  ...                    2008.0
# 1                  0          1           0  ...                    2006.0
# 2                  0          1           1  ...                    2013.0
# 3                  0          1           0  ...                    2014.0
# 4                  0          1           1  ...                    2000.0
# ...              ...        ...         ...  ...                       ...
# 41083              0          1           0  ...                    2014.0
# 41084              0          0           1  ...                    2006.0
# 41085              0          1           1  ...                    1900.0
# 41086              0          1           1  ...                    1900.0
# 41087              1          2           1  ...                    1900.0
#
#        Promo2  Promo2SinceWeek  Promo2SinceYear  PromoInterval  months  Years  \
# 0           0              0.0              0.0              0       9   2015
# 1           1             14.0           2011.0              1       9   2015
# 2           0              0.0              0.0              0       9   2015
# 3           0              0.0              0.0              0       9   2015
# 4           0              0.0              0.0              0       9   2015
# ...       ...              ...              ...            ...     ...    ...
# 41083       1             31.0           2013.0              1       8   2015
# 41084       0              0.0              0.0              0       8   2015
# 41085       0              0.0              0.0              0       8   2015
# 41086       0              0.0              0.0              0       8   2015
# 41087       1             22.0           2012.0              3       8   2015
#
#        DayOfYear  WeekOfYear  dayType
# 0            260          38        0
# 1            260          38        0
# 2            260          38        0
# 3            260          38        0
# 4            260          38        0
# ...          ...         ...      ...
# 41083        213          31        1
# 41084        213          31        1
# 41085        213          31        1
# 41086        213          31        1
# 41087        213          31        1
#
# [41088 rows x 22 columns]

# %%
train.to_csv('../data/train_model.csv')
test.to_csv('../data/test_model.csv')
