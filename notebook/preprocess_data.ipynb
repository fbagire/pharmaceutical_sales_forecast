# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import numpy as np
import warnings
import importlib
import sys
plt.rcParams["patch.force_edgecolor"] = True
plt.style.use('fivethirtyeight')
mpl.rc('patch', edgecolor = 'dimgray', linewidth=1)
# %matplotlib inline

# %%
warnings.filterwarnings('ignore')

# %%
sys.path.append("..")

# %%
from myscripts import logger_comb

# %%
from myscripts import preprocess_data

# %%
train=pd.read_csv("../data/train.csv",low_memory=False,parse_dates=[2],index_col=[0])
print(train.shape)
train.head()
# Out:
# (1017209, 18)
#    Store DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1         5  2015-07-31   5263        555     1      1            0
# 1      2         5  2015-07-31   6064        625     1      1            0
# 2      3         5  2015-07-31   8314        821     1      1            0
# 3      4         5  2015-07-31  13995       1498     1      1            0
# 4      5         5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
test=pd.read_csv("../data/test.csv",low_memory=False,parse_dates=[4],index_col=0)
print(test.shape)
test.head()
# Out:
# (41088, 17)
#    Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  SchoolHoliday  \
# 0   1      1          4 2015-09-17   1.0      1            0              0
# 1   2      3          4 2015-09-17   1.0      1            0              0
# 2   3      7          4 2015-09-17   1.0      1            0              0
# 3   4      8          4 2015-09-17   1.0      1            0              0
# 4   5      9          4 2015-09-17   1.0      1            0              0
#
#   StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0         c          a               1270.0                        9.0
# 1         a          a              14130.0                       12.0
# 2         a          c              24000.0                        4.0
# 3         a          a               7520.0                       10.0
# 4         a          c               2030.0                        8.0
#
# ...

# %%
store=pd.read_csv("../data/store.csv",low_memory=False,parse_dates=[4,index_col=0)
print(store.shape)
store.head()
# Out:
# (1115, 9)
#       StoreType Assortment  CompetitionDistance CompetitionOpenSinceMonth  \
# Store
# 1             c          a               1270.0                         9
# 2             a          a                570.0                        11
# 3             a          a              14130.0                        12
# 4             c          c                620.0                         9
# 5             a          a              29910.0                         4
#
#        CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# Store
# 1                        2008.0       0              NaN              NaN
# 2                        2007.0       1             13.0           2010.0
# 3                        2006.0       1             14.0           2011.0
# 4                        2009.0       0              NaN              NaN
# 5                        2015.0       0              NaN              NaN
#
#          PromoInterval
# Store
# ...
